# %%
import torch
torch.__version__
# Out:
# '0.4.0'

# %% [markdown]
# **The data is a subset of the Global Web-based English data. We use the US and UK texts that are freely available from corpus.byu.edu. train.txt is the concatenation of w_bg_g.txt and w_us_g.txt. valid.txt is the concatentation of w_bg_b.txt and w_us_b.txt.**
#
# We choose to use this corpus because it is very informal; much of its text originates from online blog posts

# %%
# %run main.py --save './glowbe-model.pt' --cuda --data './data/glowbe/' --epochs 20
# Out:
# /home/paperspace/pytorch-examples/word_language_model/main.py:163: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(model.parameters(), args.clip)
# | epoch   1 |   200/  921 batches | lr 20.00 | ms/batch 60.62 | loss  7.79 | ppl  2418.35
# | epoch   1 |   400/  921 batches | lr 20.00 | ms/batch 59.93 | loss  6.79 | ppl   890.95
# | epoch   1 |   600/  921 batches | lr 20.00 | ms/batch 60.65 | loss  6.43 | ppl   621.25
# | epoch   1 |   800/  921 batches | lr 20.00 | ms/batch 59.90 | loss  6.26 | ppl   525.60
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 59.88s | valid loss  6.29 | valid ppl   538.57
# -----------------------------------------------------------------------------------------
# | epoch   2 |   200/  921 batches | lr 20.00 | ms/batch 61.11 | loss  6.15 | ppl   466.61
# ...

# %%
# !cp glowbe-model.pt glowbe-model@20.pt

# %%
# %run main.py --save './glowbe-model@100.pt' --cuda --data './data/glowbe/' --epochs 100
# Out:
# /home/paperspace/pytorch-examples/word_language_model/main.py:163: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(model.parameters(), args.clip)
# | epoch   1 |   200/  921 batches | lr 20.00 | ms/batch 60.16 | loss  7.79 | ppl  2418.35
# | epoch   1 |   400/  921 batches | lr 20.00 | ms/batch 59.56 | loss  6.79 | ppl   890.95
# | epoch   1 |   600/  921 batches | lr 20.00 | ms/batch 59.78 | loss  6.43 | ppl   621.25
# | epoch   1 |   800/  921 batches | lr 20.00 | ms/batch 60.35 | loss  6.26 | ppl   525.60
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 59.70s | valid loss  6.29 | valid ppl   538.57
# -----------------------------------------------------------------------------------------
# | epoch   2 |   200/  921 batches | lr 20.00 | ms/batch 61.45 | loss  6.15 | ppl   466.61
# ...

# %% [markdown]
# **With gender_7_pronouns lens**

# %%
# %run main.py --save './glowbe-gender_7_pronouns-model.pt' --cuda --data './data/glowbe/' --epochs 20 --eval_batch_size 1
# Out:
# /home/paperspace/pytorch-examples/word_language_model/main.py:180: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   for p in model.parameters():
# | epoch   1 |   200/  921 batches | lr 20.00 | ms/batch 22.84 | loss  7.92 | ppl  2747.91
# | epoch   1 |   400/  921 batches | lr 20.00 | ms/batch 22.53 | loss  6.86 | ppl   950.43
# | epoch   1 |   600/  921 batches | lr 20.00 | ms/batch 22.69 | loss  6.51 | ppl   670.89
# | epoch   1 |   800/  921 batches | lr 20.00 | ms/batch 22.56 | loss  6.33 | ppl   560.31
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 35.37s | valid loss  6.35 | valid ppl   574.50
# -----------------------------------------------------------------------------------------
# | epoch   2 |   200/  921 batches | lr 20.00 | ms/batch 23.07 | loss  6.21 | ppl   495.33
# ...

# %%
# %run main.py --save './glowbe-gender_7_pronouns-model@100.pt' --cuda --data './data/glowbe/' --epochs 100 --eval_batch_size 1
# Out:
# /home/paperspace/pytorch-examples/word_language_model/main.py:184: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(model.parameters(), args.clip)
# | epoch   1 |   200/  921 batches | lr 20.00 | ms/batch 20.07 | loss  7.92 | ppl  2747.91
# | epoch   1 |   400/  921 batches | lr 20.00 | ms/batch 19.84 | loss  6.86 | ppl   950.43
# | epoch   1 |   600/  921 batches | lr 20.00 | ms/batch 19.87 | loss  6.51 | ppl   670.89
# | epoch   1 |   800/  921 batches | lr 20.00 | ms/batch 19.79 | loss  6.33 | ppl   560.31
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 30.07s | valid loss  6.35 | valid ppl   574.50
# -----------------------------------------------------------------------------------------
# | epoch   2 |   200/  921 batches | lr 20.00 | ms/batch 19.67 | loss  6.21 | ppl   495.33
# ...

# %%
# %run main.py --save './wikitext-2-gender_7_pronouns-model@40.pt' --use-lens --cuda --data './data/wikitext-2/' --epochs 40 --eval_batch_size 1
# Out:
# /home/paperspace/pytorch-examples/word_language_model/main.py:184: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(model.parameters(), args.clip)
# | epoch   1 |   200/ 2983 batches | lr 20.00 | ms/batch 15.52 | loss  7.72 | ppl  2249.22
# | epoch   1 |   400/ 2983 batches | lr 20.00 | ms/batch 15.44 | loss  6.92 | ppl  1015.99
# | epoch   1 |   600/ 2983 batches | lr 20.00 | ms/batch 15.35 | loss  6.53 | ppl   683.20
# | epoch   1 |   800/ 2983 batches | lr 20.00 | ms/batch 15.41 | loss  6.35 | ppl   574.35
# | epoch   1 |  1000/ 2983 batches | lr 20.00 | ms/batch 15.26 | loss  6.18 | ppl   484.36
# | epoch   1 |  1200/ 2983 batches | lr 20.00 | ms/batch 15.22 | loss  6.12 | ppl   452.95
# | epoch   1 |  1400/ 2983 batches | lr 20.00 | ms/batch 15.47 | loss  5.99 | ppl   400.54
# | epoch   1 |  1600/ 2983 batches | lr 20.00 | ms/batch 15.50 | loss  6.00 | ppl   404.25
# ...

# %%
# %run main.py --save './wikitext-2-gender_7_pronouns-model@seed1@40.pt' --use-lens --cuda --data './data/wikitext-2/' --seed 1 --epochs 40 --eval_batch_size 1
# Out:
# /home/paperspace/pytorch-examples/word_language_model/main.py:184: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(model.parameters(), args.clip)
# | epoch   1 |   200/ 2983 batches | lr 20.00 | ms/batch 15.48 | loss  7.73 | ppl  2272.20
# | epoch   1 |   400/ 2983 batches | lr 20.00 | ms/batch 15.30 | loss  6.92 | ppl  1008.76
# | epoch   1 |   600/ 2983 batches | lr 20.00 | ms/batch 15.37 | loss  6.52 | ppl   678.10
# | epoch   1 |   800/ 2983 batches | lr 20.00 | ms/batch 15.32 | loss  6.34 | ppl   565.06
# | epoch   1 |  1000/ 2983 batches | lr 20.00 | ms/batch 15.32 | loss  6.17 | ppl   477.59
# | epoch   1 |  1200/ 2983 batches | lr 20.00 | ms/batch 15.36 | loss  6.10 | ppl   446.35
# | epoch   1 |  1400/ 2983 batches | lr 20.00 | ms/batch 15.39 | loss  5.99 | ppl   401.12
# | epoch   1 |  1600/ 2983 batches | lr 20.00 | ms/batch 15.46 | loss  6.01 | ppl   406.00
# ...

# %%
# %run main.py --save './wiki@seed1@40.pt' --cuda --data './data/wikitext-2/' --seed 1 --epochs 40 --eval_batch_size 1
# Out:
# /home/paperspace/pytorch-examples/word_language_model/main.py:188: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(model.parameters(), args.clip)
# | epoch   1 |   200/ 2983 batches | lr 20.00 | ms/batch 13.31 | loss  7.64 | ppl  2082.26
# | epoch   1 |   400/ 2983 batches | lr 20.00 | ms/batch 13.17 | loss  6.85 | ppl   943.79
# | epoch   1 |   600/ 2983 batches | lr 20.00 | ms/batch 13.20 | loss  6.49 | ppl   656.17
# | epoch   1 |   800/ 2983 batches | lr 20.00 | ms/batch 13.17 | loss  6.30 | ppl   541.96
# | epoch   1 |  1000/ 2983 batches | lr 20.00 | ms/batch 13.19 | loss  6.14 | ppl   464.59
# | epoch   1 |  1200/ 2983 batches | lr 20.00 | ms/batch 13.22 | loss  6.06 | ppl   429.04
# | epoch   1 |  1400/ 2983 batches | lr 20.00 | ms/batch 13.01 | loss  5.95 | ppl   383.99
# | epoch   1 |  1600/ 2983 batches | lr 20.00 | ms/batch 13.02 | loss  5.95 | ppl   384.46
# ...

# %%
# %run main.py --save './wiki@seed2@40.pt' --cuda --data './data/wikitext-2/' --seed 2 --epochs 40 --eval_batch_size 1
# Out:
# /home/paperspace/pytorch-examples/word_language_model/main.py:188: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(model.parameters(), args.clip)
# | epoch   1 |   200/ 2983 batches | lr 20.00 | ms/batch 13.10 | loss  7.65 | ppl  2100.19
# | epoch   1 |   400/ 2983 batches | lr 20.00 | ms/batch 13.13 | loss  6.86 | ppl   953.60
# | epoch   1 |   600/ 2983 batches | lr 20.00 | ms/batch 12.99 | loss  6.48 | ppl   652.51
# | epoch   1 |   800/ 2983 batches | lr 20.00 | ms/batch 13.03 | loss  6.30 | ppl   542.76
# | epoch   1 |  1000/ 2983 batches | lr 20.00 | ms/batch 12.90 | loss  6.14 | ppl   463.35
# | epoch   1 |  1200/ 2983 batches | lr 20.00 | ms/batch 12.87 | loss  6.05 | ppl   425.10
# | epoch   1 |  1400/ 2983 batches | lr 20.00 | ms/batch 13.00 | loss  5.94 | ppl   378.80
# | epoch   1 |  1600/ 2983 batches | lr 20.00 | ms/batch 13.03 | loss  5.95 | ppl   383.34
# ...

# %%
# %run main.py --save './wikitext-2-gender_7_pronouns-model@seed2@40.pt' --use-lens True --cuda --data './data/wikitext-2/' --seed 2 --epochs 40 --eval_batch_size 1
# Out:
# /home/paperspace/pytorch-examples/word_language_model/main.py:188: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(model.parameters(), args.clip)
# | epoch   1 |   200/ 2983 batches | lr 20.00 | ms/batch 15.97 | loss  7.74 | ppl  2296.70
# | epoch   1 |   400/ 2983 batches | lr 20.00 | ms/batch 15.71 | loss  6.92 | ppl  1009.36
# | epoch   1 |   600/ 2983 batches | lr 20.00 | ms/batch 15.72 | loss  6.51 | ppl   671.60
# | epoch   1 |   800/ 2983 batches | lr 20.00 | ms/batch 15.56 | loss  6.35 | ppl   570.39
# | epoch   1 |  1000/ 2983 batches | lr 20.00 | ms/batch 15.68 | loss  6.18 | ppl   482.55
# | epoch   1 |  1200/ 2983 batches | lr 20.00 | ms/batch 15.73 | loss  6.12 | ppl   454.20
# | epoch   1 |  1400/ 2983 batches | lr 20.00 | ms/batch 15.91 | loss  6.00 | ppl   401.91
# | epoch   1 |  1600/ 2983 batches | lr 20.00 | ms/batch 16.09 | loss  6.01 | ppl   408.79
# ...

# %%
# %run main.py --save './wikitext-2-gender_7_pronouns-model@seed3@40.pt' --use-lens True --cuda --data './data/wikitext-2/' --seed 3 --epochs 40 --eval_batch_size 1
# Out:
# /home/paperspace/pytorch-examples/word_language_model/main.py:188: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(model.parameters(), args.clip)
# | epoch   1 |   200/ 2983 batches | lr 20.00 | ms/batch 17.38 | loss  7.73 | ppl  2274.37
# | epoch   1 |   400/ 2983 batches | lr 20.00 | ms/batch 18.23 | loss  6.92 | ppl  1012.07
# | epoch   1 |   600/ 2983 batches | lr 20.00 | ms/batch 18.08 | loss  6.52 | ppl   678.46
# | epoch   1 |   800/ 2983 batches | lr 20.00 | ms/batch 17.70 | loss  6.34 | ppl   567.00
# | epoch   1 |  1000/ 2983 batches | lr 20.00 | ms/batch 18.37 | loss  6.18 | ppl   480.65
# | epoch   1 |  1200/ 2983 batches | lr 20.00 | ms/batch 17.77 | loss  6.10 | ppl   447.93
# | epoch   1 |  1400/ 2983 batches | lr 20.00 | ms/batch 17.70 | loss  5.98 | ppl   396.81
# | epoch   1 |  1600/ 2983 batches | lr 20.00 | ms/batch 17.78 | loss  6.00 | ppl   403.32
# ...

# %%
# %run main.py --save './wiki@seed3@40.pt' --cuda --data './data/wikitext-2/' --seed 3 --epochs 40 --eval_batch_size 1
# Out:
# /home/paperspace/pytorch-examples/word_language_model/main.py:188: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(model.parameters(), args.clip)
# | epoch   1 |   200/ 2983 batches | lr 20.00 | ms/batch 15.04 | loss  7.64 | ppl  2086.58
# | epoch   1 |   400/ 2983 batches | lr 20.00 | ms/batch 15.12 | loss  6.87 | ppl   958.82
# | epoch   1 |   600/ 2983 batches | lr 20.00 | ms/batch 15.37 | loss  6.49 | ppl   655.88
# | epoch   1 |   800/ 2983 batches | lr 20.00 | ms/batch 14.82 | loss  6.29 | ppl   540.97
# | epoch   1 |  1000/ 2983 batches | lr 20.00 | ms/batch 14.72 | loss  6.14 | ppl   463.17
# | epoch   1 |  1200/ 2983 batches | lr 20.00 | ms/batch 15.15 | loss  6.06 | ppl   427.06
# | epoch   1 |  1400/ 2983 batches | lr 20.00 | ms/batch 14.76 | loss  5.94 | ppl   381.68
# | epoch   1 |  1600/ 2983 batches | lr 20.00 | ms/batch 14.99 | loss  5.95 | ppl   383.06
# ...
